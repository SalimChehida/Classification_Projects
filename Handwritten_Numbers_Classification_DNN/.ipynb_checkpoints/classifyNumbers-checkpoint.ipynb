# %% [markdown]
# # Import

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import sys,os
from importlib import reload

import fidle
# run_id, run_dir, datasets_dir = fidle.init('MNIST1')

# %% [markdown]
# # Load Data

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("x_train : ",x_train.shape)
print("y_train : ",y_train.shape)
print("x_test  : ",x_test.shape)
print("y_test  : ",y_test.shape)
# Out:
# x_train :  (60000, 28, 28)
# y_train :  (60000,)
# x_test  :  (10000, 28, 28)
# y_test  :  (10000,)

# %%
import tensorflow as tf
path = './mnist.zip'
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(path)
len(train_images)
# Out:
# 60000

# %% [markdown]
# # Normalize Data

# %%
print('Before normalization : Min={}, max={}'.format(x_train.min(),x_train.max()))

xmax=x_train.max()
x_train = x_train / xmax
x_test  = x_test  / xmax

print('After normalization  : Min={}, max={}'.format(x_train.min(),x_train.max()))
# Out:
# Before normalization : Min=0, max=255
# After normalization  : Min=0.0, max=1.0

# %%
fidle.scrawler.images(x_train, y_train, [27],  x_size=5,y_size=5, colorbar=True, save_as='01-one-digit')
fidle.scrawler.images(x_train, y_train, range(5,41), columns=12, save_as='02-many-digits')

# %% [markdown]
# # Create and train the model

# %%
hidden1     = 100
hidden2     = 100

model = keras.Sequential([
    keras.layers.Input((28,28)),
    keras.layers.Flatten(),
    keras.layers.Dense( hidden1, activation='relu'),
    keras.layers.Dense( hidden2, activation='relu'),
    keras.layers.Dense( 10,      activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

batch_size  = 512
epochs      =  16

history = model.fit(  x_train, y_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      validation_data = (x_test, y_test))
# Out:
# Epoch 1/16
# 118/118 [==============================] - 2s 9ms/step - loss: 0.5714 - accuracy: 0.8432 - val_loss: 0.2524 - val_accuracy: 0.9264
# Epoch 2/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.2204 - accuracy: 0.9364 - val_loss: 0.1826 - val_accuracy: 0.9474
# Epoch 3/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.1636 - accuracy: 0.9522 - val_loss: 0.1487 - val_accuracy: 0.9576
# Epoch 4/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.1311 - accuracy: 0.9617 - val_loss: 0.1280 - val_accuracy: 0.9604
# Epoch 5/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.1069 - accuracy: 0.9680 - val_loss: 0.1105 - val_accuracy: 0.9656
# Epoch 6/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0910 - accuracy: 0.9726 - val_loss: 0.0995 - val_accuracy: 0.9698
# Epoch 7/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0777 - accuracy: 0.9771 - val_loss: 0.0922 - val_accuracy: 0.9724
# Epoch 8/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0663 - accuracy: 0.9809 - val_loss: 0.0931 - val_accuracy: 0.9722
# Epoch 9/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0587 - accuracy: 0.9826 - val_loss: 0.0863 - val_accuracy: 0.9748
# Epoch 10/16
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0507 - accuracy: 0.9854 - val_loss: 0.0842 - val_accuracy: 0.9739
# Epoch 11/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0445 - accuracy: 0.9872 - val_loss: 0.0872 - val_accuracy: 0.9734
# Epoch 12/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0408 - accuracy: 0.9883 - val_loss: 0.0814 - val_accuracy: 0.9750
# Epoch 13/16
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0339 - accuracy: 0.9905 - val_loss: 0.0837 - val_accuracy: 0.9746
# Epoch 14/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0309 - accuracy: 0.9915 - val_loss: 0.0802 - val_accuracy: 0.9767
# Epoch 15/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0274 - accuracy: 0.9925 - val_loss: 0.0814 - val_accuracy: 0.9758
# Epoch 16/16
# 118/118 [==============================] - 1s 7ms/step - loss: 0.0259 - accuracy: 0.9931 - val_loss: 0.0787 - val_accuracy: 0.9773

# %% [markdown]
# # Evaluate the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss     :', score[0])
print('Test accuracy :', score[1])
fidle.scrawler.history(history, figsize=(6,4), save_as='03-history')
# Out:
# Test loss     : 0.07871608436107635
# Test accuracy : 0.9772999882698059

# %% [markdown]
# # Classify

# %%
y_sigmoid = model.predict(x_test)
y_pred    = np.argmax(y_sigmoid, axis=-1)

fidle.scrawler.images(x_test, y_test, range(0,20), columns=12, x_size=1, y_size=1, y_pred=y_pred, save_as='04-predictions')
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %% [markdown]
# # Plot errors

# %%
errors=[ i for i in range(len(x_test)) if y_pred[i]!=y_test[i] ]
errors=errors[:min(24,len(errors))]
fidle.scrawler.images(x_test, y_test, errors[:20], columns=6, x_size=2, y_size=2, y_pred=y_pred, save_as='05-some-errors')
#fidle.scrawler.confusion_matrix(y_test,y_pred,range(10),normalize=True, save_as='06-confusion-matrix')
#fidle.end()
